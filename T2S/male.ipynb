# %%
male = ["am_michael", "am_fenrir", "am_puck", "am_echo", "am_eric", "am_liam", "am_onyx", "am_santa", "am_adam","bm_george", "bm_fable", "bm_lewis", "bm_daniel"]

# %%
from IPython.display import Audio, display
for i in male:
    file = f"{i}.wav"
    display(Audio(file, autoplay=True))
    print(file)
