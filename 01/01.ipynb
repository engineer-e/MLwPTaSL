# %% [markdown]
# # Chapter 1 : Giving Computers the ability to Learn from Data

# %% [markdown]
# ## 1. Building Intelligent Machine to transform Data into Knowledge

# %% [markdown]
# ## 2. The Three different Type of Machine Learning

# %% [markdown]
# ### 1.Making Prediction about the future with Supervisied Learning

# %% [markdown]
# #### 1. Classification for predicting a class label

# %% [markdown]
# #### 2. Regression for predicting a continuous outcome

# %% [markdown]
# ### 2. Solving interactive problem with Reinforcement Learning

# %% [markdown]
# ### 3. Discover the hidden structure with Unsupervised Learning

# %% [markdown]
# #### 1. Finding subgroup with clustering

# %% [markdown]
# #### 2. Dimensionality Reduction with Data Compression

# %% [markdown]
# ## 3. The Introduction to Basic Terminology and Notation

# %% [markdown]
# ### 1. Notations and Conventions used in this book.

# %% [markdown]
# ### 2. Machine learning Terminology

# %% [markdown]
# ## 4. A roadmap to building the machine learning system

# %% [markdown]
# ### 1. Preprocessing - getting the data into shape

# %% [markdown]
# ### 2. Training and Selecting the Predective Model

# %% [markdown]
# ### 3. Evaluating the model and Predicting the unseen data instances

# %% [markdown]
# ## 5. Using Python for Machine Learning

# %% [markdown]
# ### 1. Installing Python and Packages from the Python Package Index

# %% [markdown]
# ### 2. Using Anaconda Python Distribution and package manager

# %% [markdown]
# ### 3. Packages for Scientific Computing, Data Science and Machine Learning

# %% [markdown]
# ## 6. Summary
